# %%
# variables --- mutables no mutables

# built-in function id()

a=10
print(id(a))
a=11
print(id(a))

# b-i function isinstance(,)
isinstance(a,int)

# b-i function type
print(f"type of var 'a' --> {type(a)}")

# if else flows
# if (a==10):      ( others: if (a==10 or a==20) )
# if a in [3,11]:
# if elif else

# while loop for input process, checking data type 'strict'
print('\n--------------INPUT WITH INTEGER CONDITION-----------------\n')

flag1 = False
b = input('plis give a integer value: ')
print(f"INICIO: b value is: {b} and type is {type(b)}\n")
#b = int(b)
while ( flag1 == False ):  
  print(f"WHILE: b value is: {b} and type is {type(b)}")  
# if isinstance(b,int): 
  if 'int' in str(type(b)):     
    print(f"IF: b value is: {b} and type is {type(b)}\n")  
    flag1 =True
    b=int(b)
  else:
    print(f"ELSE: b value is: {b} and type is {type(b)}\n")  
    b = input('plis give a integer value: ')

if (b <100):
  print('menor q 100')
elif (b==100):
  print('igual a 100')
else:
  print('superior a 100')
# Out:
# 9793376
# 9793408
# type of var 'a' --> <class 'int'>
#
# --------------INPUT VALUES CONDITION-----------------
#
# INICIO: b value is: 3 and type is <class 'str'>
#
# WHILE: b value is: 3 and type is <class 'str'>
# ELSE: b value is: 3 and type is <class 'str'>
#
# WHILE: b value is: p and type is <class 'str'>
# ELSE: b value is: p and type is <class 'str'>
#
# WHILE: b value is: '10 and type is <class 'str'>
# ELSE: b value is: '10 and type is <class 'str'>
