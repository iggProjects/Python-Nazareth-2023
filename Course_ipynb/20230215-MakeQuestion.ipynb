# %%
"""
    raw_input https://stackoverflow.com/questions/12772766/raw-input-placeholder
"""

def make_question(question, *answers):
    print(f"{question}")
    print
    for i, answer in enumerate(answers, 1):
        print(i, '-', answer)

    print()
    return input('Your answer is: ') 

#myQuestion='Are you a Lucky person? '
#answers=['Yes','No']
answer = make_question('Are you a Lucky person? ','yes','Nooooo')
print(answer)
