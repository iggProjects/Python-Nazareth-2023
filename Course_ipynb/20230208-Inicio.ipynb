# %%
print ("Jelouuu")
# Out:
# Jelouuu

# %%
input("cómo te llamas")

# %%
#@title Texto de título predeterminado
name=input("Cómo te llamas ? ")
# Out:
# Cómo te llamas ? iñaki

# %%
print(name)
# Out:
# iñaki

# %%
apellido="Gainza"

# %%
print(apellido)
# Out:
# Gainza

# %%
print(name); print(apellido)
# Out:
# Iñaki
# Gainza

# %%
import sys; print(sys.version)
# Out:
# 3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]

# %%
n_suerte=int(input("núm de la suerte ? "))
print("juega con " + str(n_suerte*2.1122))
print(type(n_suerte))
print(f"num a apostar {n_suerte*1.23}")
# Out:
# núm de la suerte ? 5
# juega con 10.561
# <class 'int'>
# num a apostar 6.15

# %%
print("Hola", 2023, "Agura", 5_000_000_000)
# Out:
# Hola 2023 Agura 5000000000

# %%
hijos = input("¿Cuántos hijos tienes?")
print(hijos*5)
hijos = int(input("¿Cuántos hijos tienes?"))
print(hijos*5)
# Out:
# ¿Cuántos hijos tienes?2
# 22222
# ¿Cuántos hijos tienes?3
# 15

# %%
def numbers():return 1,2,3;
# print(f"la var a es {a=numbers()} y es de tipo {type(a)}")
a = numbers()
print(f"la var a es {a} y es de tipo {type(a)}")
# Out:
# la var a es (1, 2, 3) y es de tipo <class 'tuple'>

# %%
iva = 21
#print(f"iva es {iva}")
precio_sin_iva=(float(input("Diga el precio sin iva -> ")))
#print(f"precio sin iva es {precio_sin_iva}")
print(f"precio con iva del {iva} --> {precio_sin_iva * (100 + iva)/100}")
print(f"type of result --> {type(precio_sin_iva * (100 + iva)/100)}")
# Out:
# Diga el precio sin iva -> 101.23
# precio con iva del 21 --> 122.4883
# type of result --> <class 'float'>

# %%
print("Hola", 2023, "Agura", 5_000_000_000)
print("Hola", type(2023), "Agura", type(5_000_000_000))
# Out:
# Hola 2023 Agura 5000000000
# Hola <class 'int'> Agura <class 'int'>

# %%
# Cálculo del precio con iva
iva = "20" #@param ["10", "20", "25"]
iva =float(iva)
precio_sin_iva = 100 #@param {type:"number"}
print(f"precio sin iva --> {precio_sin_iva}")
print(f"precio con iva del {iva} % --> {precio_sin_iva * (100 + iva)/100}")
print(f"type of result --> {type(precio_sin_iva * (100 + iva)/100)}")
# Out:
# precio sin iva --> 100
# precio con iva del 20.0 % --> 120.0
# type of result --> <class 'float'>
