# %%
# READING CSV FILE
# call script with one parameter: csv file

import csv
import sys
import pandas as pd

####
#nombre_archivo=sys.argv[1]
#nombre_archivo='./ChinaVirusData.csv'
#print(f"\ncsv file is:  {nombre_archivo}\n")

####
# load csv file in local drive like json
# from google.colab import files
# nombre_archivo = files.upload()
# print(f"\ncsv file is:  {nombrearchivo}\n")

###
# https://towardsdatascience.com/different-ways-to-connect-google-drive-to-a-google-colab-notebook-pt-1-de03433d2f7a
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

# libraries for the files in google drive
from pydrive.auth import GoogleAuth
from google.colab import drive
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
file_id = '/1CBE2m-8GBV5CydoOIR3_DexnqhpDowN5/view?usp=share_link' #<-- You add in here the id from you google drive file, you can find it
#file_id = 'https://drive.google.com/file/d/1CBE2m-8GBV5CydoOIR3_DexnqhpDowN5/view?usp=share_link' #<-- You add in here the id from you google drive file, you can find it
download = drive.CreateFile({'id': file_id})

# Download the file to a local disc
download.GetContentFile('ChinaVirusData.csv')
df  = pd.read_csv("ChinaVirusData.csv")
df.head()

lineas_pagina=30

def pausar():
	userInput = input('Presiona ENTER para continuar CTRL-C para salir. ')

campos = []
filas = []

with open(nombre_archivo, 'r') as archivo_csv:
	# Creo Objeto csv reader
	lector_csv = csv.reader(archivo_csv)

	campos = next(lector_csv)

	for fila in lector_csv:
		filas.append(fila)

	print(f'Total Filas: {lector_csv.line_num}')

linea_inicio=0
linea_fin=lineas_pagina

while linea_inicio <= len(filas):
	# Presento Titulo de Columnas
	for col in campos:
		print('%14s'%col, end="")
	print()
	
	for fila in filas[linea_inicio:(linea_inicio+lineas_pagina)]:
		for col in fila:
			print('%14s'%col[:5], end="")
		print()
	linea_inicio+=lineas_pagina
	pausar()
	print()
# Out:
# Mounted at /content/gdrive/
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pydrive/files.py in FetchMetadata(self, fields, fetch_all)
#     234       try:
# --> 235         metadata = self.auth.service.files().get(fileId=file_id,
#     236                                                  fields=fields)\
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# ...
